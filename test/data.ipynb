# %%
import httpx, time, json

# %%
base_url = "https://www.imf.org/external/datamapper/api/v"
def get_dataset():
        
    r = httpx.get(base_url)
    r.raise_for_status()
    return r.json()
    
get_dataset()
# Out:
# {'api': {'version': '3', 'output-method': 'json'}}
