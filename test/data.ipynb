# %%
import httpx, time, json
import pandas as pd

# %%
import httpx
import json

base_url = "https://api.imf.org/external/sdmx/3.0"

def get_dataset(endpoints):
    # Enable follow_redirects=True to handle the IMF 302 routing shift smoothly
    with httpx.Client(timeout=httpx.Timeout(45.0, connect=15.0), follow_redirects=True) as client:
        r = client.get(
            f'{base_url}{endpoints}', 
            headers={"Accept": "application/json"}
        )
        r.raise_for_status()
        data = r.json()
        
        # 1. Build the dictionary mapping flow IDs to Names
        flows = data["data"]["dataflows"]
        dataflows = {f["id"]: f["name"] for f in flows}
        
        # 2. Save the full API raw response
        with open('/mnt/D06A89C26A89A5B6/projects/portfolio/Hermes/test/data1.json', 'w', encoding='utf-8') as f:
            json.dump(data, f, indent=4)
            
        # 3. Save your custom filtered dictionary directly to data.json
        with open('/mnt/D06A89C26A89A5B6/projects/portfolio/Hermes/test/data.json', 'w', encoding='utf-8') as f:
            json.dump(dataflows, f, indent=4, ensure_ascii=False)

get_dataset('/structure/dataflow')

# %%
import httpx, pandas as pd, io

url = "https://api.imf.org/external/sdmx/3.0/data/dataflow/IMF.STA/CPI/~/USA.CPI._T.IX.M"
r = httpx.get(url, headers={"Accept": "text/csv"}, params={"c[TIME_PERIOD]": "ge:2018-M01"}, follow_redirects=True, timeout=30)

print(r.status_code)
df = pd.read_csv(io.StringIO(r.text))
df
# Out:
# 200
#    STRUCTURE[;]        STRUCTURE_ID ACTION COUNTRY INDEX_TYPE COICOP_1999  \
# 0      dataflow  IMF.STA:CPI(5.0.0)      R     USA        CPI          _T
# 1      dataflow  IMF.STA:CPI(5.0.0)      R     USA        CPI          _T
# 2      dataflow  IMF.STA:CPI(5.0.0)      R     USA        CPI          _T
# 3      dataflow  IMF.STA:CPI(5.0.0)      R     USA        CPI          _T
# 4      dataflow  IMF.STA:CPI(5.0.0)      R     USA        CPI          _T
# ..          ...                 ...    ...     ...        ...         ...
# 95     dataflow  IMF.STA:CPI(5.0.0)      R     USA        CPI          _T
# 96     dataflow  IMF.STA:CPI(5.0.0)      R     USA        CPI          _T
# 97     dataflow  IMF.STA:CPI(5.0.0)      R     USA        CPI          _T
# 98     dataflow  IMF.STA:CPI(5.0.0)      R     USA        CPI          _T
# 99     dataflow  IMF.STA:CPI(5.0.0)      R     USA        CPI          _T
#
#    TYPE_OF_TRANSFORMATION FREQUENCY TIME_PERIOD   OBS_VALUE  ...  \
# 0                      IX         M    2018-M01  113.671519  ...
# 1                      IX         M    2018-M02  114.186985  ...
# 2                      IX         M    2018-M03  114.445176  ...
# 3                      IX         M    2018-M04  114.900106  ...
# 4                      IX         M    2018-M05  115.377966  ...
# ..                    ...       ...         ...         ...  ...
# 95                     IX         M    2026-M01  149.160191  ...
# 96                     IX         M    2026-M02  149.863223  ...
# 97                     IX         M    2026-M03  151.435300  ...
# 98                     IX         M    2026-M04  152.722587  ...
# 99                     IX         M    2026-M05  153.687020  ...
#
#     DECIMALS_DISPLAYED  REPORTING_PERIOD_TYPE  TRANSFORMATION  UNIT  \
# 0                  NaN                    NaN             NaN   NaN
# 1                  NaN                    NaN             NaN   NaN
# 2                  NaN                    NaN             NaN   NaN
# 3                  NaN                    NaN             NaN   NaN
# 4                  NaN                    NaN             NaN   NaN
# ..                 ...                    ...             ...   ...
# 95                 NaN                    NaN             NaN   NaN
# 96                 NaN                    NaN             NaN   NaN
# 97                 NaN                    NaN             NaN   NaN
# 98                 NaN                    NaN             NaN   NaN
# 99                 NaN                    NaN             NaN   NaN
#
#     DERIVATION_TYPE  OVERLAP REFERENCE_PERIOD COMMON_REFERENCE_PERIOD STATUS  \
# 0                 O       OL            2010A                   2010A    NaN
# 1                 O       OL            2010A                   2010A    NaN
# 2                 O       OL            2010A                   2010A    NaN
# 3                 O       OL            2010A                   2010A    NaN
# 4                 O       OL            2010A                   2010A    NaN
# ..              ...      ...              ...                     ...    ...
# 95                O       OL            2010A                   2010A    NaN
# 96                O       OL            2010A                   2010A    NaN
# 97                O       OL            2010A                   2010A    NaN
# 98                O       OL            2010A                   2010A    NaN
# 99                O       OL            2010A                   2010A    NaN
#
#    IFS_FLAG
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# ..      ...
# 95     True
# 96     True
# 97     True
# 98     True
# 99     True
#
# [100 rows x 22 columns]
